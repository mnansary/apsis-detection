# %%
import pandas as pd
d_1 = pd.read_excel("./Sample_Small/Sample_Small/1/1.xlsx")
d_1

# /home/rezwanul/Desktop/Apsis_Bangla_Handwritten/DataSet/HTR/Sample_Small/Sample_Small/1
# Out:
# <ipython-input-1-8e8833d7080e>:2: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   d_1 = pd.read_excel("./Sample_Small/Sample_Small/1/1.xlsx")
#            Id         Word
# 0     1_1_1_1         কথা
# 1     1_1_1_2      প্রকাশ
# 2     1_1_2_1  বৈচিত্র্যময়
# 3     1_1_2_2           এই
# 4     1_1_2_3     পৃথিবীর
# ..        ...          ...
# 310  1_3_12_5            '
# 311  1_3_12_6            -
# 312  1_3_12_7          এর
# 313  1_3_12_8        পথচলা
# 314  1_3_12_9            ।
#
# [315 rows x 2 columns]

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread("./Sample_Small/Sample_Small/1/1_1.jpg")
img = cv2.rectangle(img,(795,102),(1290,183),(255,0,0),2)
img = cv2.rectangle(img,(211,281),(1818,433),(255,0,0),2)
img = cv2.rectangle(img,(235,423),(2112,597),(255,0,0),2)
plt.imshow(img)
plt.show()

# <xmin>795</xmin>
# <ymin>102</ymin>
# <xmax>1290</xmax>
# <ymax>183</ymax>

# <xmin>211</xmin>
# <ymin>281</ymin>
# <xmax>1818</xmax>
# <ymax>433</ymax>

# <xmin>235</xmin>
# <ymin>423</ymin>
# <xmax>2112</xmax>
# <ymax>597</ymax>

# %%
import xml.etree.ElementTree as ET


def read_content(xml_file: str):

    tree = ET.parse(xml_file)
    root = tree.getroot()

    list_with_all_boxes = []

    for boxes in root.iter('object'):

        filename = root.find('filename').text

        ymin, xmin, ymax, xmax = None, None, None, None

        ymin = int(boxes.find("bndbox/ymin").text)
        xmin = int(boxes.find("bndbox/xmin").text)
        ymax = int(boxes.find("bndbox/ymax").text)
        xmax = int(boxes.find("bndbox/xmax").text)

        list_with_single_boxes = [xmin, ymin, xmax, ymax]
        list_with_all_boxes.append(list_with_single_boxes)

    return filename, list_with_all_boxes

name, boxes = read_content("./Sample_Small/Sample_Small/1/Lines/1_1.xml")

# %%
name
# Out:
# '1_1.jpg'

# %%
boxes
# Out:
# [[795, 102, 1290, 183],
#  [211, 281, 1818, 433],
#  [235, 423, 2112, 597],
#  [210, 597, 1791, 753],
#  [212, 739, 2124, 902],
#  [194, 930, 1833, 1072],
#  [203, 1060, 2063, 1232],
#  [198, 1216, 2112, 1386],
#  [187, 1418, 1833, 1530],
#  [203, 1579, 2031, 1716],
#  [198, 1700, 2135, 1890],
#  [168, 1937, 1217, 2053]]

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread("./Sample_Small/Sample_Small/1/1_1.jpg")
for box in boxes:
#     print(box[0], box[1], box[2], box[3])
    img = cv2.rectangle(img,(box[0], box[1]),(box[2], box[3]),(255,0,0),2)
    plt.imshow(img)
    plt.show()
